# %%
import random

# %%
#dir(random)

# %%
import math

# %%
from math import sqrt

# %%
import sys

# %%
import sys
print(sys.argv)
# Out:
# ['/home/carlabertacche/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py', '-f', '/home/carlabertacche/.local/share/jupyter/runtime/kernel-28eb12dc-3a48-417c-b033-d722639d535e.json']

# %%
N = 10000 #numero di coppie da generare
M = 0

#meglio fare funzione che restituisce x, y

for i in range(N):
    x = random.random()
    y = random.random()
    #totale.append([x,y])
    if(x**2 + y**2 <=1):
        #cerchio.append([x,y])
        M += 1
        stima_pi = 4 * M / N


print("M ", M)

print("prima stima del pi greco: ", stima_pi)



#ora provo con valor medio
totale3 = []



def coordinates() :
        a = random.random()
        return a

def cerchio():
    x = coordinates()
    y = coordinates()
    area = x**2 + y**2
    return area

 

def stima():
    M2 = 0
    for i in range(N):
        #totale2 = coordinates()
        area = cerchio()
        if area <= 1:
            M2 += 1
            #totale3.append(totale2)
    stima2_pi = 4 * M2 / N
    return stima2_pi

dev_num = []


k = 10
somma_tot = 0
for i in range (k):
    somma_tot += stima()

valor_medio_new = somma_tot / k
for i in range (k):
    dev_std_new = math.sqrt((valor_medio_new - stima())**2 / (k-1))
    #somma.append(somma_singola)
    #valor_medio2 = media(somma_tot)
    #valor_medi.append(valor_medio2)
#valor_medio_new = somma_tot / k
#dev_std_new = deviazione(k, valor_medio_new)

print("media: ", valor_medio_new)
print("dev standard: ", dev_std_new)
# Out:
# M  7850
# prima stima del pi greco:  3.14
# media:  3.1418399999999997
# dev standard:  0.005546666666666589
